# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
Images=ImageDataGenerator(rescale=1./255)
Images=Images.flow_from_directory("E:\STIP TASKS\Cat_or_Dog_Images_Folder",target_size=(90,90))
# Out:
# Found 24998 images belonging to 2 classes.

# %%
Directory=r'E:\STIP TASKS\Cat_or_Dog_Images_Folder'
Categories=["Cat","Dog"]

# %%
import os
for category in Categories:
    path=os.path.join(Directory,category)
    print(path)
# Out:
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Dog

# %%
import os
for category in Categories:
    path=os.path.join(Directory,category)
    for img in os.listdir(path):
        print(os.path.join(path,img))
        break
# Out:
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\0.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Dog\0.jpg

# %%
import os
for category in Categories:
    path=os.path.join(Directory,category)
    for img in os.listdir(path):
        img_path=os.path.join(path,img)
        labels=Categories.index(category)
        print(labels)
        break
# Out:
# 0
# 1

# %%
import os
from keras.preprocessing import image
for category in Categories:
    path=os.path.join(Directory,category)
    for img in os.listdir(path):
        img_path=os.path.join(path,img)
        labels=Categories.index(category)
        load_image=image.load_img(img_path,target_size=(90,90))
        print(image.img_to_array(load_image))
        break
# Out:
# [[[204. 165.  88.]
#   [210. 171.  94.]
#   [215. 176.  99.]
#   ...
#   [247. 210. 130.]
#   [245. 207. 126.]
#   [241. 202. 123.]]
#
#  [[204. 165.  88.]
#   [210. 171.  94.]
#   [215. 176.  99.]
#   ...
#   [247. 211. 133.]
#   [245. 208. 128.]
#   [242. 203. 124.]]
#
#  [[205. 166.  89.]
#   [211. 172.  95.]
#   [214. 175.  98.]
#   ...
#   [246. 214. 137.]
#   [246. 210. 132.]
#   [245. 206. 127.]]
#
#  ...
#
#  [[160. 125.  57.]
#   [163. 128.  60.]
#   [164. 129.  61.]
#   ...
#   [  3.   4.   0.]
#   [  3.   4.   0.]
#   [  2.   3.   0.]]
#
#  [[156. 125.  58.]
#   [158. 127.  60.]
#   [160. 129.  62.]
#   ...
#   [  3.   3.   1.]
#   [  3.   3.   1.]
#   [  3.   3.   1.]]
#
#  [[153. 122.  55.]
#   [157. 126.  59.]
#   [158. 127.  60.]
#   ...
#   [  2.   2.   0.]
#   [  2.   2.   0.]
#   [  2.   2.   0.]]]
# [[[120. 118. 131.]
#   [110. 107. 124.]
#   [157. 156. 162.]
#   ...
#   [140. 142. 154.]
#   [139. 141. 153.]
#   [136. 136. 146.]]
#
#  [[124. 122. 135.]
# ...

# %%
import os
from keras.preprocessing import image
import cv2
import matplotlib.pyplot as plt
for category in Categories:
    path=os.path.join(Directory,category)
    for img in os.listdir(path):
        img_path=os.path.join(path,img)
        labels=Categories.index(category)
        arr=cv2.imread(img_path)
        plt.imshow(arr)
        break

# %%
data=[]
import os
from keras.preprocessing import image
import cv2
import matplotlib.pyplot as plt
count=1
for category in Categories:
    path=os.path.join(Directory,category)
    for img in os.listdir(path):
        img_path=os.path.join(path,img)
        labels=Categories.index(category)
        print(img_path)
        Img=image.load_img(img_path,target_size=(90,90))
       
        Img=image.img_to_array(Img)
        data.append([Img,labels])
# Out:
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\0.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\1.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\100.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\1000.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10000.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10001.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10002.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10003.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10004.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10005.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10006.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10007.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10008.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10009.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\1001.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10010.jpg
# E:\STIP TASKS\Cat_or_Dog_Images_Folder\Cat\10011.jpg
# ...

# %%
count=0
for i in data:
    if count==2:
        break
    count+=1
    print(i)
# Out:
# [array([[[204., 165.,  88.],
#         [210., 171.,  94.],
#         [215., 176.,  99.],
#         ...,
#         [247., 210., 130.],
#         [245., 207., 126.],
#         [241., 202., 123.]],
#
#        [[204., 165.,  88.],
#         [210., 171.,  94.],
#         [215., 176.,  99.],
#         ...,
#         [247., 211., 133.],
#         [245., 208., 128.],
#         [242., 203., 124.]],
#
#        [[205., 166.,  89.],
#         [211., 172.,  95.],
#         [214., 175.,  98.],
#         ...,
#         [246., 214., 137.],
#         [246., 210., 132.],
#         [245., 206., 127.]],
#
#        ...,
#
#        [[160., 125.,  57.],
#         [163., 128.,  60.],
#         [164., 129.,  61.],
#         ...,
#         [  3.,   4.,   0.],
#         [  3.,   4.,   0.],
#         [  2.,   3.,   0.]],
#
#        [[156., 125.,  58.],
#         [158., 127.,  60.],
#         [160., 129.,  62.],
#         ...,
#         [  3.,   3.,   1.],
#         [  3.,   3.,   1.],
# ...

# %%
len(data)
# Out:
# 24998

# %%
import random
random.shuffle(data)
X=[]
Y=[]
for features,label in data:
    X.append(features)
    Y.append(label)

# %%
import numpy as np
X=np.array(X)
Y=np.array(Y)

# %%
print(len(X))
print(len(Y))
# Out:
# 24998
# 24998

# %%
#import pickle
#pickle.dump(X,open("E:\STIP TASKS\Cat_or_Dog_pickle_files\Images.pkl","wb"))
#pickle.dump(Y,open("E:\STIP TASKS\Cat_or_Dog_pickle_files\Images_Label.pkl","wb"))

# %%
#Images=pickle.load(open("E:\STIP TASKS\Cat_or_Dog_pickle_files\Images.pkl","rb"))
#Labels=pickle.load(open("E:\STIP TASKS\Cat_or_Dog_pickle_files\Images_Label.pkl","rb"))

# %%
X.shape
# Out:
# (24998, 90, 90, 3)

# %%
Y.shape
# Out:
# (24998,)

# %%
#Feature Scaling
X=X/255

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model=Sequential()
model.add(Conv2D(150,(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(200,(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128,input_shape=X.shape[1:],activation="relu"))

model.add(Dense(250,activation="relu"))

model.add(Dense(200,activation="relu"))

model.add(Dense(150,activation="relu"))

model.add(Dense(100,activation="relu"))

model.add(Dense(50,activation="relu"))

model.add(Dense(2,activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.fit(X,Y,validation_split=0.2,epochs=5)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 1000s 2s/step - loss: 0.6425 - accuracy: 0.6170 - val_loss: 0.5962 - val_accuracy: 0.6768
# Epoch 2/5
# 625/625 [==============================] - 1109s 2s/step - loss: 0.5310 - accuracy: 0.7407 - val_loss: 0.4995 - val_accuracy: 0.7598
# Epoch 3/5
# 625/625 [==============================] - 1044s 2s/step - loss: 0.4605 - accuracy: 0.7833 - val_loss: 0.4737 - val_accuracy: 0.7700
# Epoch 4/5
# 625/625 [==============================] - 1071s 2s/step - loss: 0.3756 - accuracy: 0.8286 - val_loss: 0.4682 - val_accuracy: 0.7920
# Epoch 5/5
# 625/625 [==============================] - 1050s 2s/step - loss: 0.2895 - accuracy: 0.8746 - val_loss: 0.5317 - val_accuracy: 0.7930

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 88, 88, 150)       4200
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 44, 44, 150)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 42, 42, 200)       270200
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 21, 21, 200)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 88200)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               11289728
# _________________________________________________________________
# dense_1 (Dense)              (None, 250)               32250
# ...

# %%
from keras.preprocessing.image import load_img, img_to_array

img=load_img(r"C:\Users\DELL\Downloads\dog_.jpg",target_size=(90,90))
image=img_to_array(img)
test_image1=np.expand_dims(image,axis=0)
model.predict(test_image1)
# Out:
# array([[0., 1.]], dtype=float32)

# %%
if model.predict(test_image1)[0][0]==1.:
    print("It is Cat")
else:
    print("It is Dog")
# Out:
# It is Dog
